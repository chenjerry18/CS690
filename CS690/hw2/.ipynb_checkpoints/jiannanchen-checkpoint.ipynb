# %% [markdown]
# # CS 690 Homework2
#
# ## Overview
#
# In this homework, I read the two datasets obtained from Moodle. One is the wholesale data with six missing values, another is the wholesale data without missing values. To deal with the missing value problem, I applied four methods which are ignoring the tuples with the missing values, filling the missing datapoints with a global constant, performing linear interpolation, and inserting attribute mean values. In the visualization part, I used two plots for each method. The plots on the left are visualizations of the **Wholesale customer data-missing** dataset after dealing with missing values, the plots on the right are visualizations of the **Wholesale customers data** dataset. All of these visualizations contain **box zoom**, **wheel zoom**, **pan**, **hover**, and **slider**. Some of the codes refers to Bokeh Examples on [Github](https://github.com/bokeh/bokeh/tree/0.12.9)
#
# **Reference:** [Bokeh Examples](https://github.com/bokeh/bokeh/tree/0.12.9)

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from pandas import DataFrame as df

from bokeh.core.properties import field
from ipywidgets import interact
from bokeh.io import push_notebook, output_notebook
from bokeh.layouts import layout
from bokeh.models import (
    ColumnDataSource, HoverTool, SingleIntervalTicker, Slider, Button, Label,
    CategoricalColorMapper, CustomJS,
)
from bokeh.palettes import Spectral6, brewer
from bokeh.plotting import figure, show
from bokeh.layouts import column, widgetbox, row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="55cf24b6-52c6-4e0b-b743-483b95f65e0f">Loading BokehJS ...</span>
#     </div>

# %%
def process_data_missing(choice = 0):
    raw_data = df.from_csv("Wholesale customers data-missing.csv")
    
    new_data = None
    
    raw_data = raw_data.reset_index()

    result = raw_data.isnull()
    
    cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']
    
    df_dict = {}
    
    for col in cols:
        stat = col + ' == True'
        df_dict[col] = list(result.query(stat).index)

    if choice == 0:
        #return data_frame after ignoring tuples with missing datapoints.
        new_data = raw_data.dropna()
    elif choice == 1:
        #return data_frame after filling missing datapoints with global constant -1.
        new_data = raw_data.fillna(-20)
    elif choice == 2:
        #return data_frame after performing linear interpolation at missing datapoints.
        new_data = raw_data.interpolate(method='linear')
    elif choice == 3:
        #return data_frame after filling missing datapoints with attribute mean.
        new_data = raw_data.fillna(raw_data.mean())
    
    return new_data, df_dict

# %%
def process_data_all():
    raw_data = df.from_csv("Wholesale customers data.csv")
    
    raw_data = raw_data.reset_index()

    return raw_data

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(0)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by ignoring the tuples with missing datapoints
#
# There are two scatter plots below. The left one visualizes the results after ignoring the tuples with missing datapoints, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="e803c4f0-d50a-49b3-ba98-9250046c5cb3"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("e803c4f0-d50a-49b3-ba98-9250046c5cb3");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("e803c4f0-d50a-49b3-ba98-9250046c5cb3");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'e803c4f0-d50a-49b3-ba98-9250046c5cb3' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8943f22c-9c4e-4f2a-b566-c143691761f4":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"75767ce2-762f-41e0-b4cd-5684ea335296","subtype":"Figure","type":"Plot"},"ticker":{"id":"eb083db4-e737-46e5-91d9-1065dbd4ab01","type":"BasicTicker"}},"id":"9b64e3d5-6096-4e0b-9b64-1596311bde94","type":"Grid"},{"attributes":{},"id":"b80fba43-f5c3-42a6-b44c-8fb65ddabd2e","type":"SaveTool"},{"attributes":{},"id":"88729658-0019-4acf-9399-bae89c207726","type":"SaveTool"},{"attributes":{},"id":"4d0f0dd4-c2a8-4690-ad70-06e36207c606","type":"BasicTicker"},{"attributes":{"overlay":{"id":"035a4da0-5468-40b6-b07d-b5126ffaf688","type":"BoxAnnotation"}},"id":"b5e599ab-c285-48e0-be05-59b89001ff6e","type":"BoxZoomTool"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"1712436f-f545-4d06-a1ed-fd4749880b80","type":"BasicTickFormatter"},"plot":{"id":"2f259cbe-99c7-4926-a7be-8b46d4995555","subtype":"Figure","type":"Plot"},"ticker":{"id":"ddebd142-0b6f-48de-87c5-1a665695b13b","type":"SingleIntervalTicker"}},"id":"8fbe3675-7d7b-47c9-9e47-e5e800074599","type":"LinearAxis"},{"attributes":{},"id":"bc871b46-14cf-46f4-a8b2-c1b597d46d60","type":"BasicTickFormatter"},{"attributes":{"factors":["channel:2,regions:2","channel:1,regions:1","channel:2,regions:1","channel:1,regions:3","channel:1,regions:2","missing","channel:2,regions:3"],"palette":["#3288bd","#99d594","#e6f598","#ffffbf","#fee08b","#fc8d59","#d53e4f"]},"id":"84ffe28e-6f50-45a2-98e5-76c4a7c71094","type":"CategoricalColorMapper"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"323e7a0e-c769-4fb8-884f-d8644143d1c5","type":"Circle"},{"attributes":{"plot":{"id":"2f259cbe-99c7-4926-a7be-8b46d4995555","subtype":"Figure","type":"Plot"},"ticker":{"id":"4d0f0dd4-c2a8-4690-ad70-06e36207c606","type":"BasicTicker"}},"id":"6939d38c-200c-4ad3-b071-5620179ae30f","type":"Grid"},{"attributes":{"callback":null},"id":"db30ee5f-02af-4359-bed4-84937acb6ad9","type":"DataRange1d"},{"attributes":{},"id":"1712436f-f545-4d06-a1ed-fd4749880b80","type":"BasicTickFormatter"},{"attributes":{"source":{"id":"cfa5fae6-37dd-442d-a253-07778a7a0fe8","type":"ColumnDataSource"}},"id":"ef07d0b6-21d8-4c41-b8f4-54da62ee9772","type":"CDSView"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"bc871b46-14cf-46f4-a8b2-c1b597d46d60","type":"BasicTickFormatter"},"plot":{"id":"75767ce2-762f-41e0-b4cd-5684ea335296","subtype":"Figure","type":"Plot"},"ticker":{"id":"254bd168-cb36-4feb-80e5-a420b5b6e95a","type":"SingleIntervalTicker"}},"id":"69963b34-f767-48c3-897c-54101a21ed33","type":"LinearAxis"},{"attributes":{"interval":20000},"id":"ddebd142-0b6f-48de-87c5-1a665695b13b","type":"SingleIntervalTicker"},{"attributes":{},"id":"169889e4-2b17-451e-b293-48133a830033","type":"ResetTool"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"9aba25e9-822d-458a-9451-028b00c4e88f","type":"BasicTickFormatter"},"plot":{"id":"2f259cbe-99c7-4926-a7be-8b46d4995555","subtype":"Figure","type":"Plot"},"ticker":{"id":"db0e508b-1a2f-4f98-a915-a7560d1c82a1","type":"SingleIntervalTicker"}},"id":"1873b2b4-a75c-4bc4-92ef-e462fbf1038e","type":"LinearAxis"},{"attributes":{"label":{"field":"legend_names"},"renderers":[{"id":"aa8257b8-0866-49ce-8992-6c3b831255a7","type":"GlyphRenderer"}]},"id":"32454516-c5cf-4b2f-8daf-03e5ba19ad88","type":"LegendItem"},{"attributes":{"plot":null,"text":"Grocery vs.  Fresh with Missing Values"},"id":"666581a2-8fb6-404d-a588-374e1ad5871b","type":"Title"},{"attributes":{},"id":"9d2f3ff9-1118-4cec-9a9b-f999a12b151d","type":"HelpTool"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Fresh","$x"],["Grocery","$y"]]},"id":"b40b8140-5025-4dd2-877b-9c07577d7be2","type":"HoverTool"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Fresh","$x"],["Grocery","$ ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(1)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by filling the missing values with a global constant -20
#
# There are two scatter plots below. The left one visualizes the results after filling the missing values with a global constant -20, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="86c2a883-f610-4db9-9851-cf7dfddae9c8"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("86c2a883-f610-4db9-9851-cf7dfddae9c8");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("86c2a883-f610-4db9-9851-cf7dfddae9c8");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '86c2a883-f610-4db9-9851-cf7dfddae9c8' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f016cf21-d11b-47ce-b69f-0b87576d9f75":{"roots":{"references":[{"attributes":{},"id":"5935a692-2809-45c5-9e32-b4a75a5af48f","type":"HelpTool"},{"attributes":{"callback":null},"id":"eb864d0c-3c5b-431d-8940-e82d803d3806","type":"DataRange1d"},{"attributes":{},"id":"cf8d6a02-6214-4313-8a29-ed84292b9dcb","type":"ResetTool"},{"attributes":{},"id":"aace67f7-8a80-4e29-bb24-60dd63f6830b","type":"BasicTickFormatter"},{"attributes":{},"id":"f6d7ab50-c0fb-4397-a6e6-10c921fe0d9e","type":"BasicTicker"},{"attributes":{},"id":"e55db738-cd27-4748-ad0d-d2d39645165b","type":"BasicTickFormatter"},{"attributes":{"label":{"field":"legend_names"},"renderers":[{"id":"6e9c1e4c-3372-4f63-a61c-83cb02db949a","type":"GlyphRenderer"}]},"id":"1522e28e-9ab8-4d1a-9d54-d65858c44e8a","type":"LegendItem"},{"attributes":{},"id":"abd3a931-20a1-45d6-b80e-61bd09279442","type":"PanTool"},{"attributes":{},"id":"7c4d5c1c-6830-44ba-82fc-d76739c01cd7","type":"WheelZoomTool"},{"attributes":{"interval":20000},"id":"8f30bde8-ee12-4fa2-8fbb-dbfc0f2fd712","type":"SingleIntervalTicker"},{"attributes":{"source":{"id":"c4d3d7f6-1a9e-4dfc-8b9c-238019f3ac9d","type":"ColumnDataSource"}},"id":"70e57455-2e3b-4962-98cf-2a8dbdb13821","type":"CDSView"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"5e786569-3233-4fe4-9e87-7f42a171178a","type":"BasicTickFormatter"},"plot":{"id":"9ddc9b9d-2f31-4a75-adb0-b2a3fb4207ab","subtype":"Figure","type":"Plot"},"ticker":{"id":"8f30bde8-ee12-4fa2-8fbb-dbfc0f2fd712","type":"SingleIntervalTicker"}},"id":"651351a5-d4dc-48ac-9550-2e1c80607a88","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"abd3a931-20a1-45d6-b80e-61bd09279442","type":"PanTool"},{"id":"4cb798a8-1b35-463d-8eeb-9384e72dbb32","type":"WheelZoomTool"},{"id":"776f1e72-398d-4981-9305-3b877604d3a5","type":"BoxZoomTool"},{"id":"34d18cd9-f4b5-4158-a1c0-dd2464df5ee6","type":"SaveTool"},{"id":"cf8d6a02-6214-4313-8a29-ed84292b9dcb","type":"ResetTool"},{"id":"25915a8b-1c3d-4db4-8b8a-4e3d98c5bacc","type":"HelpTool"},{"id":"bcf632a2-55ae-4d9d-a44f-b897ebb61153","type":"HoverTool"}]},"id":"c1a99c0a-81a6-445f-8a36-1699b97c727b","type":"Toolbar"},{"attributes":{},"id":"eb5ba712-080d-4717-97b5-87daff55c097","type":"BasicTicker"},{"attributes":{"factors":["channel:2,regions:2","channel:1,regions:1","channel:2,regions:1","channel:1,regions:3","channel:1,regions:2","missing","channel:2,regions:3"],"palette":["#3288bd","#99d594","#e6f598","#ffffbf","#fee08b","#fc8d59","#d53e4f"]},"id":"a2d86b92-6b9a-4693-a006-303507f5c5d3","type":"CategoricalColorMapper"},{"attributes":{"dimension":1,"plot":{"id":"e6cbb79f-4380-4dca-b5bc-59c158862fe8","subtype":"Figure","type":"Plot"},"ticker":{"id":"f6d7ab50-c0fb-4397-a6e6-10c921fe0d9e","type":"BasicTicker"}},"id":"b00bc1a3-a92a-4f61-8f1d-aa6f5c7007cf","type":"Grid"},{"attributes":{"source":{"id":"dddf7d95-43a5-42c8-b200-438e9b68b423","type":"ColumnDataSource"}},"id":"029b732d-2c46-4a03-9672-d0296522f5e2","type":"CDSView"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"35469ffc-acfa-4957-924f-6f24af5c38ee","type":"BasicTickFormatter"},"plot":{"id":"e6cbb79f-4380-4dca-b5bc-59c158862fe8","subtype":"Figure","type":"Plot"},"ticker":{"id":"d7a0350b-6105-4bd1-bf84-559335abc088","type":"SingleIntervalTicker"}},"id":"be18baa7-522e-4532-84f6-e422f6acf08f","type":"LinearAxis"},{"attributes":{"overlay":{"id":"47f5c291-5219-4be0-89e4-ba5114d533d8","type":"BoxAnnotation"}},"id":"3f0423e7-66fc-4611-8975-9026bb3a64ce","type":"BoxZoomTool"},{"attributes":{},"id":"5e786569-3233-4fe4-9e87-7f42a171178a","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"950e2796-57bc-4667-aaeb-77a66a47d299","type":"Circle"},{"attributes":{},"id":"230ee719-aa8 ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])
# Out:
# <function __main__.update_notebook>

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(2)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by performing linear interpolation
#
# There are two scatter plots below. The left one visualizes the results after performing linear interpolation, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d6e8f319-9e3f-4eab-ba06-3eb49d59bbf2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("d6e8f319-9e3f-4eab-ba06-3eb49d59bbf2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d6e8f319-9e3f-4eab-ba06-3eb49d59bbf2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd6e8f319-9e3f-4eab-ba06-3eb49d59bbf2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"687873de-5226-4a18-92d5-53aedf2f4b67":{"roots":{"references":[{"attributes":{"dimension":1,"plot":{"id":"acf56dd2-4cf6-47d8-a144-c08cc4ea8035","subtype":"Figure","type":"Plot"},"ticker":{"id":"736341e5-40d1-4c6b-838c-26be98d766e5","type":"BasicTicker"}},"id":"5c630e6c-1b27-446d-87eb-3577d57ebb4d","type":"Grid"},{"attributes":{},"id":"053d35b5-a3be-4876-adf8-c1d64934b11a","type":"LinearScale"},{"attributes":{},"id":"dc599dbb-0c08-4f08-9630-a16f8c71c045","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"field":"legend_names","transform":{"id":"dda0f4c8-29df-4c9e-b9eb-8ae4aa227622","type":"CategoricalColorMapper"}},"line_alpha":{"value":0.5},"line_color":{"value":"#7c7e71"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"a5678c8f-81d6-4f35-aa23-01851c750241","type":"Circle"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Fresh","$x"],["Grocery","$y"]]},"id":"5681bc50-118a-4970-aba2-8f37459c0433","type":"HoverTool"},{"attributes":{"callback":null},"id":"83e80b19-6ccd-4f8c-9351-e33f3a7af4a9","type":"DataRange1d"},{"attributes":{},"id":"36bc2df6-6580-4885-b9b0-c4ba3bc41778","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"fd02d4e6-e630-4bc5-8c45-8b5f7992889a","type":"Circle"},{"attributes":{"interval":20000},"id":"9be1cd7e-4933-4758-965f-4e800fa2b24c","type":"SingleIntervalTicker"},{"attributes":{"callback":null},"id":"4a8bc900-c4ac-4b77-977b-64180fd358da","type":"DataRange1d"},{"attributes":{},"id":"7ea33427-94c2-4fa3-bb43-bd1a0c78a572","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5d516c0d-5c66-41ac-82cc-f7c5d86d74ad","type":"BoxAnnotation"},{"attributes":{"overlay":{"id":"8a86088f-128d-499c-be77-eb1278b0f2c0","type":"BoxAnnotation"}},"id":"151a0cdf-ccef-433c-aa88-b1d3cec156db","type":"BoxZoomTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"8a86088f-128d-499c-be77-eb1278b0f2c0","type":"BoxAnnotation"},{"attributes":{},"id":"fc0fa820-c8b2-4ab6-aaf7-65e6ddf85ebb","type":"ResetTool"},{"attributes":{},"id":"91c2300c-bc7f-455d-a19b-79d3d9b2349c","type":"BasicTicker"},{"attributes":{"below":[{"id":"2c351a2f-ea54-4737-81ba-bf5ab7cd6dfb","type":"LinearAxis"}],"left":[{"id":"44c9eb3f-fe1e-4051-9ca3-00a88fe712ce","type":"LinearAxis"}],"plot_height":400,"plot_width":490,"renderers":[{"id":"2c351a2f-ea54-4737-81ba-bf5ab7cd6dfb","type":"LinearAxis"},{"id":"44db7904-2544-4271-8711-cfae976809dc","type":"Grid"},{"id":"44c9eb3f-fe1e-4051-9ca3-00a88fe712ce","type":"LinearAxis"},{"id":"b5460fbb-c0fa-4157-acec-157696188b2e","type":"Grid"},{"id":"8a86088f-128d-499c-be77-eb1278b0f2c0","type":"BoxAnnotation"},{"id":"c0cb48de-41be-4c96-84ce-84efbb54d4c0","type":"Legend"},{"id":"5b05038e-0654-4be6-92ce-3fdadc40c03e","type":"GlyphRenderer"}],"title":{"id":"b2b58522-b415-4419-8784-22f4f6d1b16d","type":"Title"},"toolbar":{"id":"44858a31-cb11-4b69-80f6-22389535f579","type":"Toolbar"},"x_range":{"id":"4a8bc900-c4ac-4b77-977b-64180fd358da","type":"DataRange1d"},"x_scale":{"id":"053d35b5-a3be-4876-adf8-c1d64934b11a","type":"LinearScale"},"y_range":{"id":"83e80b19-6ccd-4f8c-9351-e33f3a7af4a9","type":"DataRange1d"},"y_scale":{" ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])
# Out:
# <function __main__.update_notebook>

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(3)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by inserting attribute mean values
#
# There are two scatter plots below. The left one visualizes the results after inserting attribute mean values, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a1df5312-1a52-478d-9bf0-b36bf7205a44"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a1df5312-1a52-478d-9bf0-b36bf7205a44");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a1df5312-1a52-478d-9bf0-b36bf7205a44");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a1df5312-1a52-478d-9bf0-b36bf7205a44' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4621f9b5-7ab6-48fa-9d0a-d254536e8038":{"roots":{"references":[{"attributes":{"interval":20000},"id":"72011a58-d375-4fb6-9d13-aa90ff4a2234","type":"SingleIntervalTicker"},{"attributes":{"source":{"id":"de5dd0a0-9d87-465d-83df-a57aaf9dabde","type":"ColumnDataSource"}},"id":"f428d2bc-6fc4-4ac2-bdb2-c8b29e825787","type":"CDSView"},{"attributes":{},"id":"25e760de-7191-45ca-b022-c25dce9950fe","type":"BasicTickFormatter"},{"attributes":{"callback":null},"id":"f2835768-9f1e-4583-8d3f-4bb7752352ca","type":"DataRange1d"},{"attributes":{},"id":"dc6abee6-7228-481c-8f46-ed4fc698975f","type":"BasicTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"99209baa-8c87-4dae-9a39-57f933fb5795","type":"PanTool"},{"id":"2717fad8-43ce-4ac5-90c2-cb1bbc910866","type":"WheelZoomTool"},{"id":"6c4340b7-c4ab-4be9-8375-d23da9811807","type":"BoxZoomTool"},{"id":"b8ed403e-807c-450f-9272-2204cb3974b6","type":"SaveTool"},{"id":"6cc1a12c-45f7-4e65-9e6b-e04f8714e8bb","type":"ResetTool"},{"id":"dd06fc5e-cec5-4c61-925e-673684ae1d4e","type":"HelpTool"},{"id":"be6c6954-1351-4f57-8a8b-91f627d90be9","type":"HoverTool"}]},"id":"276bb008-7677-4a04-9a6e-9f6312fa78e8","type":"Toolbar"},{"attributes":{"dimension":1,"plot":{"id":"518ce3c1-e24a-4bf4-91a1-d047348d004f","subtype":"Figure","type":"Plot"},"ticker":{"id":"b2b0e002-1b75-4428-9b8d-6ccc9efdc50f","type":"BasicTicker"}},"id":"51596ede-d8d2-4ce2-b207-c2848b022a9f","type":"Grid"},{"attributes":{"callback":null,"column_names":["legend_names","x","y"],"data":{"legend_names":["channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","missing","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3 ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])
# Out:
# <function __main__.update_notebook>
