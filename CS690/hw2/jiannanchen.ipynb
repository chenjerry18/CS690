# %% [markdown]
# # CS 690 Homework2
#
# ## Overview
#
# In this homework, I read the two datasets obtained from Moodle. One is the wholesale data with six missing values, another is the wholesale data without missing values. To deal with the missing value problem, I applied four methods which are ignoring the tuples with the missing values, filling the missing datapoints with a global constant, performing linear interpolation, and inserting attribute mean values. In the visualization part, I used two plots for each method. The plots on the left are visualizations of the **Wholesale customer data-missing** dataset after dealing with missing values, the plots on the right are visualizations of the **Wholesale customers data** dataset. All of these visualizations contain **box zoom**, **wheel zoom**, **pan**, **hover**, and **slider**. Some of the codes refers to Bokeh Examples on [Github](https://github.com/bokeh/bokeh/tree/0.12.9)
#
# **Reference:** [Bokeh Examples](https://github.com/bokeh/bokeh/tree/0.12.9)
#
# **Notice:** Please run each part of the code individually, in case some interactors would not function if you click on 'Run all'.

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from pandas import DataFrame as df

from bokeh.core.properties import field
from ipywidgets import interact
from bokeh.io import push_notebook, output_notebook
from bokeh.layouts import layout
from bokeh.models import (
    ColumnDataSource, HoverTool, SingleIntervalTicker, Slider, Button, Label,
    CategoricalColorMapper, CustomJS,
)
from bokeh.palettes import Spectral6, brewer
from bokeh.plotting import figure, show
from bokeh.layouts import column, widgetbox, row

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="43d20917-f9f6-4908-b6e2-251170c9691f">Loading BokehJS ...</span>
#     </div>

# %%
def process_data_missing(choice = 0):
    raw_data = df.from_csv("Wholesale customers data-missing.csv")
    
    new_data = None
    
    raw_data = raw_data.reset_index()

    result = raw_data.isnull()
    
    cols = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicassen']
    
    df_dict = {}
    
    for col in cols:
        stat = col + ' == True'
        df_dict[col] = list(result.query(stat).index)

    if choice == 0:
        #return data_frame after ignoring tuples with missing datapoints.
        new_data = raw_data.dropna()
    elif choice == 1:
        #return data_frame after filling missing datapoints with global constant -1.
        new_data = raw_data.fillna(-20)
    elif choice == 2:
        #return data_frame after performing linear interpolation at missing datapoints.
        new_data = raw_data.interpolate(method='linear')
    elif choice == 3:
        #return data_frame after filling missing datapoints with attribute mean.
        new_data = raw_data.fillna(raw_data.mean())
    
    return new_data, df_dict

# %%
def process_data_all():
    raw_data = df.from_csv("Wholesale customers data.csv")
    
    raw_data = raw_data.reset_index()

    return raw_data

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(0)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by ignoring the tuples with missing datapoints
#
# There are two scatter plots below. The left one visualizes the results after ignoring the tuples with missing datapoints, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="75317b6d-25bb-475b-8899-53dfcf42a74f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("75317b6d-25bb-475b-8899-53dfcf42a74f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("75317b6d-25bb-475b-8899-53dfcf42a74f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '75317b6d-25bb-475b-8899-53dfcf42a74f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"1d105f3e-26b5-4044-8029-d01a51015cc1":{"roots":{"references":[{"attributes":{"below":[{"id":"54793770-66c4-4560-a9c9-59b6b0ac4dab","type":"LinearAxis"}],"left":[{"id":"21f13569-cd09-43e6-9994-84a3e2e2b66c","type":"LinearAxis"}],"plot_height":400,"plot_width":490,"renderers":[{"id":"54793770-66c4-4560-a9c9-59b6b0ac4dab","type":"LinearAxis"},{"id":"32bcc7e4-c610-4d86-8914-4c0e69f76fa0","type":"Grid"},{"id":"21f13569-cd09-43e6-9994-84a3e2e2b66c","type":"LinearAxis"},{"id":"2bba9345-e6c5-44b9-9aae-9ab0a368c7fc","type":"Grid"},{"id":"df5040bd-22eb-4d7f-9fbc-f7be860260a8","type":"BoxAnnotation"},{"id":"9346218d-7848-416f-8356-325c0a2708f7","type":"Legend"},{"id":"811bbd08-a693-41c3-ac51-190aa36e3ba4","type":"GlyphRenderer"}],"title":{"id":"78995cd7-7c97-4826-8c17-44bf6a8bfe32","type":"Title"},"toolbar":{"id":"d07b1d79-5680-4797-8c23-8affe81cb58f","type":"Toolbar"},"x_range":{"id":"3b923e9b-cf68-4de0-80b8-3444da536091","type":"DataRange1d"},"x_scale":{"id":"76538c72-9de8-43f1-ad29-fa5a334fa8b7","type":"LinearScale"},"y_range":{"id":"cf28aaf1-c391-401b-8f37-14bab47a5ee6","type":"DataRange1d"},"y_scale":{"id":"e57c999f-8878-42bf-a213-706f309801c6","type":"LinearScale"}},"id":"0c112cf9-a750-4533-9350-66e90bffb6a8","subtype":"Figure","type":"Plot"},{"attributes":{},"id":"6febe3eb-d606-46ed-9e5d-001c7f074709","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x","legend_names"],"data":{"legend_names":["channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions:3","channel:1,regions: ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(1)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by filling the missing values with a global constant -20
#
# There are two scatter plots below. The left one visualizes the results after filling the missing values with a global constant -20, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3d0954c3-447e-4a73-a97b-3f0abf4316ef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3d0954c3-447e-4a73-a97b-3f0abf4316ef");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3d0954c3-447e-4a73-a97b-3f0abf4316ef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3d0954c3-447e-4a73-a97b-3f0abf4316ef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a99337f2-97ac-4430-bd93-c289da56b3db":{"roots":{"references":[{"attributes":{"axis_label":"Grocery","formatter":{"id":"51c2b3d1-85ec-4e0f-a6b1-c60b6f05dda5","type":"BasicTickFormatter"},"plot":{"id":"71211fe4-4d8a-4a1e-ad68-a7360818af07","subtype":"Figure","type":"Plot"},"ticker":{"id":"e8492f9c-bdaf-47bf-a045-972f68b6199b","type":"SingleIntervalTicker"}},"id":"fa341bd6-611f-4c8a-a9e7-7e963432ea79","type":"LinearAxis"},{"attributes":{"interval":20000},"id":"944909c6-4450-4461-90fa-b779fa1b52a6","type":"SingleIntervalTicker"},{"attributes":{"plot":{"id":"c809f505-48fb-4f03-a95b-831b26a2405c","subtype":"Figure","type":"Plot"},"ticker":{"id":"f4346fa1-23f3-4f97-977e-93a7b3b5e977","type":"BasicTicker"}},"id":"b5752524-eeed-478a-a9ef-413ccdd256b6","type":"Grid"},{"attributes":{},"id":"f2db30a5-0926-4b28-a393-1af20511e1f7","type":"LinearScale"},{"attributes":{},"id":"09978533-d94c-47c6-89c6-c4880ab63776","type":"LinearScale"},{"attributes":{"items":[{"id":"1ae1cb69-9cbb-4780-99bc-60ae8e228a7f","type":"LegendItem"}],"plot":{"id":"71211fe4-4d8a-4a1e-ad68-a7360818af07","subtype":"Figure","type":"Plot"}},"id":"1e7044bc-9673-4517-a78d-f464d67d5a09","type":"Legend"},{"attributes":{"interval":20000},"id":"e8492f9c-bdaf-47bf-a045-972f68b6199b","type":"SingleIntervalTicker"},{"attributes":{"plot":{"id":"71211fe4-4d8a-4a1e-ad68-a7360818af07","subtype":"Figure","type":"Plot"},"ticker":{"id":"262fd258-76b1-48ec-a2cd-aa254a0fb549","type":"BasicTicker"}},"id":"1161b403-0120-4f55-9b60-733231278153","type":"Grid"},{"attributes":{},"id":"262fd258-76b1-48ec-a2cd-aa254a0fb549","type":"BasicTicker"},{"attributes":{},"id":"61ed521a-e261-47d7-b6ee-fa3772ad2280","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"field":"legend_names","transform":{"id":"81e4994b-89ba-4168-bc04-8f3832ddad5c","type":"CategoricalColorMapper"}},"line_alpha":{"value":0.5},"line_color":{"value":"#7c7e71"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"900eaf28-aa08-447e-8cfb-ed23cf00b294","type":"Circle"},{"attributes":{"factors":["missing","channel:2,regions:2","channel:2,regions:3","channel:1,regions:3","channel:1,regions:2","channel:1,regions:1","channel:2,regions:1"],"palette":["#3288bd","#99d594","#e6f598","#ffffbf","#fee08b","#fc8d59","#d53e4f"]},"id":"81e4994b-89ba-4168-bc04-8f3832ddad5c","type":"CategoricalColorMapper"},{"attributes":{},"id":"f4a5e78c-e8ed-481e-89e8-58da744f41d0","type":"ResetTool"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Fresh","$x"],["Grocery","$y"]]},"id":"d54fbdd0-8dc6-467f-9fbc-dbbcb53af3ec","type":"HoverTool"},{"attributes":{},"id":"d5619402-fb63-4e8c-a48d-7c4d498e2ace","type":"LinearScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"9f701f31-324b-4aed-905c-3674cdb5769d","type":"Circle"},{"attributes":{"children":[{"id":"71211fe4-4d8a-4a1e-ad68-a7360818af07","subtype":"Figure","type":"Plot"},{"id":"c809f505-48fb-4f03-a95b-831b26a2405c","subtype":"Figure","type":"Plot"}]},"id":"f6aff89f-b536-4aa1-bd93-f8d859c6278e","type":"Row"},{"attributes":{"callback":null},"id":"00af0bbc-0e3a-4391-b74d-b22c758d065f","type":"DataRange1d"},{"attributes":{"overlay":{"id":"1420bc64-e977-480a-8bb9-7c6b53165c96","type":"BoxAnnotation"}},"id":"89101d87-e228-408f-bb0a-f0acb7f7ef1a","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"1661763e-5d61-4c47-9cd3-b157543a3e76","type":"LinearAxis"}],"left":[{"id":"fa341bd6-611f-4c8a-a9e7-7e963432ea79","type":"LinearAxis"}],"plot_height":400,"plot_width":490,"renderers":[{"id":"1661763e-5d61-4c47-9cd3-b157543a3e76","type":"LinearAxis"},{"id":"1161b403-0120-4f55-9b60-733231278153","type":"Grid"},{"id":"fa341bd6-611f-4c8a-a9e7-7e963432ea79","type":"LinearAxis"},{"id":"89f7dd5c- ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])
# Out:
# <function __main__.update_notebook>

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(2)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by performing linear interpolation
#
# There are two scatter plots below. The left one visualizes the results after performing linear interpolation, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="6e1b8c43-c28e-4e25-8a8b-fed9f87904f2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("6e1b8c43-c28e-4e25-8a8b-fed9f87904f2");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6e1b8c43-c28e-4e25-8a8b-fed9f87904f2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6e1b8c43-c28e-4e25-8a8b-fed9f87904f2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"9334bfa8-a0f8-4798-86ba-94fa157c6ddf":{"roots":{"references":[{"attributes":{},"id":"b2a81b3f-2d3c-475a-b822-76da8cb06b69","type":"SaveTool"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"ef11a9e8-6846-40c8-af2c-1c2a8e29c900","type":"BasicTickFormatter"},"plot":{"id":"2f4b29a9-df05-4e69-8b0b-adaf8dd7cff9","subtype":"Figure","type":"Plot"},"ticker":{"id":"164c7e08-a054-4068-987b-842533b3bc66","type":"SingleIntervalTicker"}},"id":"38578efe-1478-4703-ad34-ab7c8ac804e7","type":"LinearAxis"},{"attributes":{"callback":null,"point_policy":"follow_mouse","tooltips":[["Fresh","$x"],["Grocery","$y"]]},"id":"083be19e-e9b7-47f3-8ad4-f8a512ab85f4","type":"HoverTool"},{"attributes":{"axis_label":"Grocery","formatter":{"id":"1bf76bd9-ee94-4810-ad7e-997b6024a012","type":"BasicTickFormatter"},"plot":{"id":"7380c8e7-4157-41ea-bb86-fe7acbe5b3c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"9a79d555-e0f0-4687-9d0e-7512ae17e188","type":"SingleIntervalTicker"}},"id":"45406abb-0fee-48fe-92af-3ab3e5bfe653","type":"LinearAxis"},{"attributes":{"interval":20000},"id":"b6fa429b-f8db-436a-81b1-6ee801518f4b","type":"SingleIntervalTicker"},{"attributes":{},"id":"17063961-6482-4984-bfc2-a8a64ae0c5a3","type":"PanTool"},{"attributes":{},"id":"1e465daf-350f-4542-9e7f-04e03e623c31","type":"LinearScale"},{"attributes":{},"id":"bfe6278c-a5af-4b1d-a3ec-37e1fbb088bd","type":"BasicTicker"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"df19cef7-08b3-475e-84c6-343beabbe3b1","type":"BoxAnnotation"},{"attributes":{"factors":["missing","channel:2,regions:2","channel:2,regions:3","channel:1,regions:3","channel:1,regions:2","channel:1,regions:1","channel:2,regions:1"],"palette":["#3288bd","#99d594","#e6f598","#ffffbf","#fee08b","#fc8d59","#d53e4f"]},"id":"c965ff4d-bf1e-41ab-a14c-080beb908da2","type":"CategoricalColorMapper"},{"attributes":{"callback":null},"id":"31799f4d-4d7c-4b9f-ae18-a3186341b3e5","type":"DataRange1d"},{"attributes":{"plot":null,"text":"Grocery vs.  Fresh with Missing Values"},"id":"854944f3-1911-4a2b-ac14-b291a7c7a006","type":"Title"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a3b4a36-d526-4507-b520-3c639f4ed956","type":"Circle"},{"attributes":{"axis_label":"Fresh","formatter":{"id":"07d97c63-04ca-4f9c-8750-ca150affd127","type":"BasicTickFormatter"},"plot":{"id":"7380c8e7-4157-41ea-bb86-fe7acbe5b3c0","subtype":"Figure","type":"Plot"},"ticker":{"id":"b6fa429b-f8db-436a-81b1-6ee801518f4b","type":"SingleIntervalTicker"}},"id":"c3171789-c247-4c83-8e9f-959e0d0b61de","type":"LinearAxis"},{"attributes":{"overlay":{"id":"df19cef7-08b3-475e-84c6-343beabbe3b1","type":"BoxAnnotation"}},"id":"cb97fe8b-0e1b-4ffd-94a6-37960f932ac7","type":"BoxZoomTool"},{"attributes":{"below":[{"id":"f1093128-dbb3-47b8-aab6-be537b9b5f3e","type":"LinearAxis"}],"left":[{"id":"38578efe-1478-4703-ad34-ab7c8ac804e7","type":"LinearAxis"}],"plot_height":400,"plot_width":490,"renderers":[{"id":"f1093128-dbb3-47b8-aab6-be537b9b5f3e","type":"LinearAxis"},{"id":"291d9134-096d-423f-a339-3c49e617a200","type":"Grid"},{"id":"38578efe-1478-4703-ad34-ab7c8ac804e7","type":"LinearAxis"},{"id":"c733b201-8b2b-4661-af34-892900510433","type":"Grid"},{"id":"75a1889b-3bb4-483d-b7b9-842e57128cec","type":"BoxAnnotation"},{"id":"6af68603-66f1-49b9-9696-855a29289859","type":"Legend"},{"id":"c4daf331-f17a-472b-9b94-1f552a637eb8","type":"GlyphRenderer"}],"title":{"id":"854944f3-1911-4a2b-ac14-b291a7c7a006","type":"Title"},"toolbar":{"id":"60789e23-2a9c-4a74-82b6-638cae08200a","type":"Toolbar"},"x_ran ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])

# %%
ws_df_all = process_data_all()

ws_df, df_dict = process_data_missing(3)

cate = list(ws_df_all.columns)

index_all = list(ws_df_all.index)
index_missing = list(ws_df.index)

channel_all = ws_df_all.loc[:, cate[0]].tolist()

regions_all = ws_df_all.loc[:, cate[1]].tolist()

xaxis_name = cate[2]
yaxis_name = cate[4]

labels_all = []

for i in range(len(index_all)):
    if index_all[i] in df_dict[yaxis_name]:
        labels_all.append('missing')
    else:
        labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))

#display data without missing data
source_all = ColumnDataSource(dict(x = ws_df_all.loc[:, xaxis_name].tolist(), y = ws_df_all.loc[:, yaxis_name].tolist(), legend_names = labels_all))

plot_all = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'without Missing Values']), plot_height=400, plot_width= 490)
plot_all.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.xaxis.axis_label = xaxis_name
plot_all.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_all.yaxis.axis_label = yaxis_name

color_mapper_all = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(labels_all)))

r_all = plot_all.circle(
    'x',
    'y',
    size=10,
    source=source_all,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)


plot_all.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))


channel_missing = ws_df.loc[:, cate[0]].tolist()

regions_missing = ws_df.loc[:, cate[1]].tolist()

label_missing = []

for i in range(len(index_missing)):
    if index_missing[i] in df_dict[yaxis_name]:
        label_missing.append('missing')
    else:
        label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))

source_missing = ColumnDataSource(dict(x = ws_df.loc[:, xaxis_name].tolist(), y = ws_df.loc[:, yaxis_name].tolist(), legend_names = label_missing))

plot_missing = figure(title=' '.join([yaxis_name, 'vs. ', xaxis_name, 'with Missing Values']), plot_height=400, plot_width= 490)
plot_missing.xaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.xaxis.axis_label = xaxis_name
plot_missing.yaxis.ticker = SingleIntervalTicker(interval=20000)
plot_missing.yaxis.axis_label = yaxis_name

# color_mapper_missing = CategoricalColorMapper(palette=brewer['Spectral'][7], factors=list(set(label_missing)))

r_missing = plot_missing.circle(
    'x',
    'y',
    size=10,
    source=source_missing,
    fill_color={'field': 'legend_names', 'transform': color_mapper_all},
    fill_alpha=0.7,
    line_color='#7c7e71',
    line_width=0.5,
    line_alpha=0.5,
    legend='legend_names',
)

plot_missing.add_tools(HoverTool(tooltips=[(xaxis_name, '$x'), (yaxis_name, '$y')], show_arrow=True, point_policy='follow_mouse'))

layouts = row(plot_missing, plot_all)

def update_notebook(x = cate[2], y = cate[3]):
    if x == y:
        pass
    else:
        
        label_missing = []
        
        for i in range(len(index_missing)):
            if index_missing[i] in df_dict[yaxis_name]:
                label_missing.append('missing')
            else:
                label_missing.append(','.join(['channel:' + str(channel_missing[i]), 'regions:'+str(regions_missing[i])]))
                
        r_missing.data_source.data['x'] = ws_df.loc[:, x].tolist()
        r_missing.data_source.data['y'] = ws_df.loc[:, y].tolist()
        r_missing.data_source.data['legend_names'] = label_missing
        
        labels_all = []

        for i in range(len(index_all)):
            if index_all[i] in df_dict[y]:
                labels_all.append('missing')
            else:
                labels_all.append(','.join(['channel:' + str(channel_all[i]), 'regions:'+str(regions_all[i])]))
        
        r_all.data_source.data['x'] = ws_df_all.loc[:, x].tolist()
        r_all.data_source.data['y'] = ws_df_all.loc[:, y].tolist()
        r_all.data_source.data['legend_names'] = labels_all
        
        plot_all.title.text = ' '.join([y, 'vs. ', x, 'without Missing Values'])
        plot_all.xaxis.axis_label = x
        plot_all.yaxis.axis_label = y
        
        plot_missing.title.text = ' '.join([y, 'vs. ', x, 'with Missing Values'])
        plot_missing.xaxis.axis_label = x
        plot_missing.yaxis.axis_label = y
        push_notebook()

# %% [markdown]
# ### Deal with the missing data by inserting attribute mean values
#
# There are two scatter plots below. The left one visualizes the results after inserting attribute mean values, the right one visualizes the original dataset which doesn't contain missing values. The missing datapoints are marked with a different color on both plots. The jupyter interactor enable you choose different attributes to be the x axis or the y axis. And the hover tells you the values of a specific datapoint on the plots.
#
# (*This plot may take a while to load on nbviewer*)

# %%
show(layouts, notebook_handle = True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="bf018184-599f-43dd-a3d1-1f110511bbdc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("bf018184-599f-43dd-a3d1-1f110511bbdc");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("bf018184-599f-43dd-a3d1-1f110511bbdc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'bf018184-599f-43dd-a3d1-1f110511bbdc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cb728fab-67a2-4f83-af25-8931548c1179":{"roots":{"references":[{"attributes":{"interval":20000},"id":"c1e03b9a-b2fc-4fb2-a9aa-42d5df15df8a","type":"SingleIntervalTicker"},{"attributes":{"callback":null},"id":"5d27259e-5a8e-4ead-aed5-ce87e1f0155b","type":"DataRange1d"},{"attributes":{},"id":"9a5eac19-8514-4c62-a995-9b80780df692","type":"BasicTickFormatter"},{"attributes":{},"id":"5012c383-76a9-4c9c-8c1a-bca2352c0ba8","type":"HelpTool"},{"attributes":{"label":{"field":"legend_names"},"renderers":[{"id":"deef2f84-e566-42e5-8e86-ee4cff33c3d6","type":"GlyphRenderer"}]},"id":"38f3c977-c83b-4b98-ae2b-76949499801d","type":"LegendItem"},{"attributes":{},"id":"1b5380f9-e3be-4e4f-a81b-1ed94fcef908","type":"PanTool"},{"attributes":{"label":{"field":"legend_names"},"renderers":[{"id":"52f8ece7-0842-4ade-a259-d86041e46c3d","type":"GlyphRenderer"}]},"id":"27aed00a-4c6d-41f9-8385-33f709e18849","type":"LegendItem"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"aa79912b-9784-4a6e-b44d-9e39f033e2e1","type":"BoxAnnotation"},{"attributes":{"data_source":{"id":"9560fbf7-69c6-4f0b-b87d-5373f7c56f13","type":"ColumnDataSource"},"glyph":{"id":"50fedf2e-323c-4b6c-a489-aef60141dbf6","type":"Circle"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"1da6c65d-42e9-491a-b1f7-d57c9766c281","type":"Circle"},"selection_glyph":null,"view":{"id":"85aeef0c-7ac3-4689-a0f5-f934ff6d0092","type":"CDSView"}},"id":"deef2f84-e566-42e5-8e86-ee4cff33c3d6","type":"GlyphRenderer"},{"attributes":{},"id":"21d76a29-2aed-401d-9130-e7ebe996b219","type":"BasicTicker"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"61f2dd11-6bf7-45d5-af67-dbf25bd46870","type":"PanTool"},{"id":"892d9ff4-30fa-42e3-a4f3-a81d9f673779","type":"WheelZoomTool"},{"id":"428f7eca-1d2b-4ac3-b285-60114300f9c3","type":"BoxZoomTool"},{"id":"551e5d9f-63d2-48c7-bbb8-c7da69a26b48","type":"SaveTool"},{"id":"ec61eb8f-46be-4a9b-85b3-92d1015d94da","type":"ResetTool"},{"id":"e4469713-09a6-4cb4-a708-80fce4329911","type":"HelpTool"},{"id":"791b84fa-81bb-45dc-82f8-c9893e890555","type":"HoverTool"}]},"id":"056a6220-6d8d-4a44-9663-099ec9947d90","type":"Toolbar"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":0.5},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"c474638f-d793-4339-b12e-b8bd5be67822","type":"Circle"},{"attributes":{"plot":null,"text":"Grocery vs.  Fresh with Missing Values"},"id":"2e2e161f-35ad-40c8-857f-68032ba16e69","type":"Title"},{"attributes":{"interval":20000},"id":"b82749e6-d5b0-4d06-b7c0-54d670f03f52","type":"SingleIntervalTicker"},{"attributes":{},"id":"8fde6f3d-b917-431c-93cc-f1817c2206ee","type":"ResetTool"},{"attributes":{"plot":null,"text":"Grocery vs.  Fresh without Missing Values"},"id":"90f5fbfd-78a5-46a1-9b9b-7dde7e231528","type":"Title"},{"attributes":{"callback":null,"column_names":["y","x","legend_names"],"data":{"legend_names":["channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel:2,regions:3","channel:2,regions:3","channel:1,regions:3","channel:1,regions:3","channel:2,regions:3","channel ...

# %%
interact(update_notebook, x = cate[2:], y = cate[2:])
